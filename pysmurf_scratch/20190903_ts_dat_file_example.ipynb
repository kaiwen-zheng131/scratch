# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from importlib import reload
import read_stream_data_gcp_save
import glob

# %%
pwd
# Out:
# 'C:\\Users\\Heather\\Documents\\Git\\scratch\\pysmurf_scratch'

# %%
files = glob.glob('1565290314/outputs/*.dat.part*')

# %%
files
# Out:
# ['1565290314/outputs\\1565291557.dat.part_00000']

# %%
timestamp, phase, mask = read_stream_data_gcp_save.read_stream_data_gcp_save(datafile=files[0])

# %%
plot(mask[0], 'x', color = 'r')

# %%
#these are the SMuRF channels
np.where(mask[0]!=-1)
# Out:
# (array([317, 381], dtype=int64),)

# %%
#plot a timestream
ts_rad = phase[0,:]
plot(ts_rad)
