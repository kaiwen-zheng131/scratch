# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from importlib import reload
import read_stream_data_gcp_save
import glob

# %%
pwd
# Out:
# 'C:\\Users\\Heather\\Documents\\Git\\scratch\\pysmurf_scratch'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is CAD1-D850
#
#  Directory of C:\Users\Heather\Documents\Git\scratch\pysmurf_scratch
#
# 09/03/2019  04:35 PM    <DIR>          .
# 09/03/2019  04:35 PM    <DIR>          ..
# 09/03/2019  04:35 PM    <DIR>          .ipynb_checkpoints
# 09/03/2019  04:35 PM    <DIR>          __pycache__
# 09/03/2019  04:35 PM    <DIR>          1565290314
# 09/03/2019  04:33 PM           126,888 20190903_ts_dat_file_example.ipynb
# 04/18/2019  11:25 AM             5,155 read_stream_data_gcp_save.py
#                2 File(s)        132,043 bytes
#                5 Dir(s)  190,612,242,432 bytes free

# %%
files = glob.glob('1565290314/outputs/*.dat.part*')

# %%
file = '1565290314/outputs\\1565319739.dat.part_00000'

# %%
timestamp, phase, mask = read_stream_data_gcp_save.read_stream_data_gcp_save(datafile=files[0])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-7f14e14ba0d9> in <module>
# ----> 1 timestamp, phase, mask = read_stream_data_gcp_save.read_stream_data_gcp_save(datafile=files[0])
#
# ~\Documents\Git\scratch\pysmurf_scratch\read_stream_data_gcp_save.py in read_stream_data_gcp_save(datafile, channel, unwrap, downsample, n_samp)
#     112         timestamp = filename.split('.')[0]
#     113
# --> 114         mask = make_mask_lookup(os.path.join(rootpath, '{}_mask.txt'.format(timestamp)))
#     115         #mask = self.make_mask_lookup(datafile.replace('.dat','_mask.txt'))
#     116
#
# ~\Documents\Git\scratch\pysmurf_scratch\read_stream_data_gcp_save.py in make_mask_lookup(mask_file)
#     131         mask_lookup (int array): An array with the GCP numbers.
#     132         """
# --> 133         mask = np.atleast_1d(np.loadtxt(mask_file))
#     134         bands = np.unique(mask // 512).astype(int)
#     135         ret = np.ones((np.max(bands)+1, 512), dtype=int) * -1
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#     924             fname = str(fname)
#     925         if _is_string_like(fname):
# --> 926             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     927             fencoding = getattr(fh, 'encoding', 'latin1')
#     928             fh = iter(fh)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     260
#     261     ds = DataSource(destpath)
# --> 262     return ds.open(path, mode, encoding=encoding, newline=newline)
#     263
#     264
#
# ~\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     616                                       encoding=encoding, newline=newline)
#     617         else:
# --> 618             raise IOError("%s not found." % path)
#     619
#     620
#
# OSError: 1565290314/outputs\1565291428_mask.txt not found.

# %%
plot(mask[2], 'x', color = 'r')

# %%
np.where(mask[0]!=-1)
# Out:
# (array([], dtype=int64),)

# %%
pA_per_phi0 = 9000000 /(2*np.pi)* (228/178)
fs = 200

# %%
S_w = []

figure(figsize = (8,6))

for i in arange(max(mask[0,:])+1):
    #get timestream and subtract out average
    ts_rad = phase[i,:] - np.mean(phase[i,:])
    ts_pA = ts_rad *pA_per_phi0
    pxx, fr = mlab.psd(ts_pA, NFFT=2**12, Fs=fs)
    pxx = np.sqrt(pxx)

    #get white noise level
    fr_1 = find_nearest(fr,0.5)
    fr_10 = find_nearest(fr,20)
    
    loglog(fr, pxx)
    #loglog(fr[fr_1:fr_10], pxx[fr_1:fr_10], color = 'r')

    wn_average = np.average(pxx[fr_1:fr_10])
    #axhline(wn_average, color = 'g')
    S_w.append(wn_average)
    
    #print(wn_average)

xlabel('$\mathrm{Hz}$')
ylabel('$\mathrm{pA/\\sqrt{Hz}}$');
tight_layout()

# %%
S_w
# Out:
# [52.99714840117221, 50.81531614889065]

# %%
d_noise = {'file':[],
    'file_number': [],
    'mask_index':[], 
    'Sw':[],
    'f0':[], 
    'Qi':[], 
    'Qc':[],
    'Q':[],
    'br': []}
        

d_noise = pd.DataFrame(d_noise)
#d_noise = dnoise[['resonator_index', 'f0', 'Qi', 'Qc', 'Q', 'br']]

d_noise
# Out:
# Empty DataFrame
# Columns: [file, file_number, mask_index, Sw, f0, Qi, Qc, Q, br]
# Index: []

# %%
files2 = ['1565290314/outputs\\1565302150.dat.part_00000',
 '1565290314/outputs\\1565302293.dat.part_00000',
 '1565290314/outputs\\1565302434.dat.part_00000',
 '1565290314/outputs\\1565302564.dat.part_00000',
 '1565290314/outputs\\1565302707.dat.part_00000',
 '1565290314/outputs\\1565302932.dat.part_00000',
 '1565290314/outputs\\1565303062.dat.part_00000',
 '1565290314/outputs\\1565303207.dat.part_00000',
 '1565290314/outputs\\1565303352.dat.part_00000',
 '1565290314/outputs\\1565303495.dat.part_00000',
 '1565290314/outputs\\1565303639.dat.part_00000',
 '1565290314/outputs\\1565303783.dat.part_00000',
 '1565290314/outputs\\1565303927.dat.part_00000',
 '1565290314/outputs\\1565304056.dat.part_00000',
 '1565290314/outputs\\1565304186.dat.part_00000',
 '1565290314/outputs\\1565304340.dat.part_00000',
 '1565290314/outputs\\1565304481.dat.part_00000',
 '1565290314/outputs\\1565304612.dat.part_00000',
 '1565290314/outputs\\1565304742.dat.part_00000',
 '1565290314/outputs\\1565304884.dat.part_00000',
 '1565290314/outputs\\1565305012.dat.part_00000',
 '1565290314/outputs\\1565305139.dat.part_00000',
 '1565290314/outputs\\1565305268.dat.part_00000',
 '1565290314/outputs\\1565305410.dat.part_00000',
 '1565290314/outputs\\1565305552.dat.part_00000',
 '1565290314/outputs\\1565305682.dat.part_00000',
 '1565290314/outputs\\1565305810.dat.part_00000',
 '1565290314/outputs\\1565305939.dat.part_00000',
 '1565290314/outputs\\1565306080.dat.part_00000',
 '1565290314/outputs\\1565306209.dat.part_00000',
 '1565290314/outputs\\1565306337.dat.part_00000',
 '1565290314/outputs\\1565306488.dat.part_00000',
 '1565290314/outputs\\1565306618.dat.part_00000',
 '1565290314/outputs\\1565306760.dat.part_00000',
 '1565290314/outputs\\1565306890.dat.part_00000',
 '1565290314/outputs\\1565307032.dat.part_00000',
 '1565290314/outputs\\1565307177.dat.part_00000',
 '1565290314/outputs\\1565307308.dat.part_00000',
 '1565290314/outputs\\1565307452.dat.part_00000',
 '1565290314/outputs\\1565307600.dat.part_00000',
 '1565290314/outputs\\1565307731.dat.part_00000',
 '1565290314/outputs\\1565307872.dat.part_00000',
 '1565290314/outputs\\1565308001.dat.part_00000',
 '1565290314/outputs\\1565308142.dat.part_00000',
 '1565290314/outputs\\1565308276.dat.part_00000',
 '1565290314/outputs\\1565308406.dat.part_00000',
 '1565290314/outputs\\1565308548.dat.part_00000',
 '1565290314/outputs\\1565308749.dat.part_00000',
 '1565290314/outputs\\1565308866.dat.part_00000',
 '1565290314/outputs\\1565308994.dat.part_00000',
 '1565290314/outputs\\1565309136.dat.part_00000',
 '1565290314/outputs\\1565309279.dat.part_00000',
 '1565290314/outputs\\1565309421.dat.part_00000',
 '1565290314/outputs\\1565309566.dat.part_00000',
 '1565290314/outputs\\1565309711.dat.part_00000',
 '1565290314/outputs\\1565309842.dat.part_00000',
 '1565290314/outputs\\1565309973.dat.part_00000',
 '1565290314/outputs\\1565310125.dat.part_00000',
 '1565290314/outputs\\1565310266.dat.part_00000',
 '1565290314/outputs\\1565310408.dat.part_00000',
 '1565290314/outputs\\1565310537.dat.part_00000',
 '1565290314/outputs\\1565310678.dat.part_00000',
 '1565290314/outputs\\1565310823.dat.part_00000',
 '1565290314/outputs\\1565310967.dat.part_00000',
 '1565290314/outputs\\1565311097.dat.part_00000',
 '1565290314/outputs\\1565311240.dat.part_00000',
 '1565290314/outputs\\1565311375.dat.part_00000',
 '1565290314/outputs\\1565311507.dat.part_00000',
 '1565290314/outputs\\1565311651.dat.part_00000',
 '1565290314/outputs\\1565311784.dat.part_00000',
 '1565290314/outputs\\1565311914.dat.part_00000',
 '1565290314/outputs\\1565312056.dat.part_00000',
 '1565290314/outputs\\1565312186.dat.part_00000',
 '1565290314/outputs\\1565312328.dat.part_00000',
 '1565290314/outputs\\1565312459.dat.part_00000',
 '1565290314/outputs\\1565312603.dat.part_00000',
 '1565290314/outputs\\1565312805.dat.part_00000',
 '1565290314/outputs\\1565312948.dat.part_00000',
 '1565290314/outputs\\1565313078.dat.part_00000',
 '1565290314/outputs\\1565313193.dat.part_00000',
 '1565290314/outputs\\1565313333.dat.part_00000',
 '1565290314/outputs\\1565313462.dat.part_00000',
 '1565290314/outputs\\1565313578.dat.part_00000',
 '1565290314/outputs\\1565313717.dat.part_00000',
 '1565290314/outputs\\1565313847.dat.part_00000',
 '1565290314/outputs\\1565313990.dat.part_00000',
 '1565290314/outputs\\1565314122.dat.part_00000',
 '1565290314/outputs\\1565314238.dat.part_00000',
 '1565290314/outputs\\1565314379.dat.part_00000',
 '1565290314/outputs\\1565314512.dat.part_00000',
 '1565290314/outputs\\1565314655.dat.part_00000']

# %%
k = 0
for file in files2:
    print (file)
    timestamp, phase, mask = read_stream_data_gcp_save.read_stream_data_gcp_save(datafile=file)
    
    file_no = k
    channels = np.where(mask[1]!=-1)
    #print(file_no)
    for i in arange(max(mask[1,:])+1):
        #get timestream and subtract out average
        ts_rad = phase[i,:] - np.mean(phase[i,:])
        ts_pA = ts_rad *pA_per_phi0
        pxx, fr = mlab.psd(ts_pA, NFFT=2**12, Fs=fs)
        pxx = np.sqrt(pxx)

        #get white noise level
        fr_1 = find_nearest(fr,0.5)
        fr_10 = find_nearest(fr,20)

        wn_average = np.average(pxx[fr_1:fr_10])
        #print(channels[0][i])
        d_noise = d_noise.append({'file': file, 'file_number': file_no, 'mask_index':channels[0][i], 'Sw':wn_average}, ignore_index=True)
    k=k+1
# Out:
# 1565290314/outputs\1565302150.dat.part_00000
# 1565290314/outputs\1565302293.dat.part_00000
# 1565290314/outputs\1565302434.dat.part_00000
# ..                                            ...          ...         ...
# 376  1565290314/outputs\1565312948.dat.part_00000         77.0       114.0
# 377  1565290314/outputs\1565312948.dat.part_00000         77.0       178.0
# 378  1565290314/outputs\1565313078.dat.part_00000         78.0       306.0
# 379  1565290314/outputs\1565313078.dat.part_00000         78.0       370.0
# 380  1565290314/outputs\1565313193.dat.part_00000         79.0        10.0
# 381  1565290314/outputs\1565313333.dat.part_00000         80.0       266.0
# 382  1565290314/outputs\1565313333.dat.part_00000         80.0       330.0
# 383  1565290314/outputs\1565313333.dat.part_00000         80.0       394.0
# 384  1565290314/outputs\1565313462.dat.part_00000         81.0        42.0
# 385  1565290314/outputs\1565313462.dat.part_00000         81.0       106.0
# 386  1565290314/outputs\1565313578.dat.part_00000         82.0       298.0
# 387  1565290314/outputs\1565313717.dat.part_00000         83.0        26.0
# 388  1565290314/outputs\1565313717.dat.part_00000         83.0        90.0
# 389  1565290314/outputs\1565313717.dat.part_00000         83.0       154.0
# 390  1565290314/outputs\1565313847.dat.part_00000         84.0       282.0
# 391  1565290314/outputs\1565313847.dat.part_00000         84.0       346.0
# 392  1565290314/outputs\1565313990.dat.part_00000         85.0        58.0
# 393  1565290314/outputs\1565313990.dat.part_00000         85.0       122.0
# 394  1565290314/outputs\1565313990.dat.part_00000         85.0       186.0
# 395  1565290314/outputs\1565314122.dat.part_00000         86.0       314.0
# 396  1565290314/outputs\1565314122.dat.part_00000         86.0       378.0
# 397  1565290314/outputs\1565314238.dat.part_00000         87.0         6.0
# 398  1565290314/outputs\1565314379.dat.part_00000         88.0       262.0
# 399  1565290314/outputs\1565314379.dat.part_00000         88.0       326.0
# 400  1565290314/outputs\1565314379.dat.part_00000         88.0       390.0
# 401  1565290314/outputs\1565314512.dat.part_00000         89.0        38.0
# 402  1565290314/outputs\1565314512.dat.part_00000         89.0       102.0
# 403  1565290314/outputs\1565314655.dat.part_00000         90.0       294.0
# 404  1565290314/outputs\1565314655.dat.part_00000         90.0       358.0
# 405  1565290314/outputs\1565314655.dat.part_00000         90.0       422.0
#
#                Sw  f0  Qi  Qc   Q  br
# 0    5.670331e+05 NaN NaN NaN NaN NaN
# 1    5.299715e+01 NaN NaN NaN NaN NaN
# 2    5.081532e+01 NaN NaN NaN NaN NaN
# 3    1.818929e+02 NaN NaN NaN NaN NaN
# 4    1.355261e+02 NaN NaN NaN NaN NaN
# 5    1.845870e+02 NaN NaN NaN NaN NaN
# 6    1.324799e+02 NaN NaN NaN NaN NaN
# 7    1.849708e+02 NaN NaN NaN NaN NaN
# 8    1.029038e+02 NaN NaN NaN NaN NaN
# 9    1.387376e+02 NaN NaN NaN NaN NaN
# 10   8.722457e+01 NaN NaN NaN NaN NaN
# 11   7.366794e+01 NaN NaN NaN NaN NaN
# 12   7.914342e+01 NaN NaN NaN NaN NaN
# 13   9.452798e+01 NaN NaN NaN NaN NaN
# 14   4.131376e+06 NaN NaN NaN NaN NaN
# 15   6.020000e+01 NaN NaN NaN NaN NaN
# 16   6.296277e+01 NaN NaN NaN NaN NaN
# 17   7.005320e+01 NaN NaN NaN NaN NaN
# 18   8.814047e+01 NaN NaN NaN NaN NaN
# 19   2.538850e+02 NaN NaN NaN NaN NaN
# 20   1.261011e+02 NaN NaN NaN NaN NaN
# 21   1.065516e+02 NaN NaN NaN NaN NaN
# 22   1.249533e+02 NaN NaN NaN NaN NaN
# 23   1.077613e+02 NaN NaN NaN NaN NaN
# 24   7.980516e+01 NaN NaN NaN NaN NaN
# 25   6.144912e+01 NaN NaN NaN NaN NaN
# 26   4.306214e+01 NaN NaN NaN NaN NaN
# 27   6.398518e+01 NaN NaN NaN NaN NaN
# 28   6.642777e+01 NaN NaN NaN NaN NaN
# 29   7.674337e+01 NaN NaN NaN NaN NaN
# ..            ...  ..  ..  ..  ..  ..
# 376  6.181281e+02 NaN NaN NaN NaN NaN
# 377  1.212099e+05 NaN NaN NaN NaN NaN
# 378  1.264721e+02 NaN NaN NaN NaN NaN
# 379  1.216255e+02 NaN NaN NaN NaN NaN
# 380  2.702384e+02 NaN NaN NaN NaN NaN
# 381  6.635608e+03 NaN NaN NaN NaN NaN
# 382  3.252544e+02 NaN NaN NaN NaN NaN
# 383  2.364692e+02 NaN NaN NaN NaN NaN
# 384  9.736882e+01 NaN NaN NaN NaN NaN
# 385  3.476947e+03 NaN NaN NaN NaN NaN
# 386  6.020921e+01 NaN NaN NaN NaN NaN
# 387  1.243279e+02 NaN NaN NaN NaN NaN
# 388  1.455801e+02 NaN NaN NaN NaN NaN
# 389  1.346005e+02 NaN NaN NaN NaN NaN
# 390  6.165023e+02 NaN NaN NaN NaN NaN
# 391  4.970169e+06 NaN NaN NaN NaN NaN
# 392  5.337413e+05 NaN NaN NaN NaN NaN
# 393  4.296544e+06 NaN NaN NaN NaN NaN
# 394  2.506724e+06 NaN NaN NaN NaN NaN
# 395  1.129701e+04 NaN NaN NaN NaN NaN
# 396  4.094959e+06 NaN NaN NaN NaN NaN
# 397  4.147537e+06 NaN NaN NaN NaN NaN
# 398  4.367036e+06 NaN NaN NaN NaN NaN
# 399  4.438074e+06 NaN NaN NaN NaN NaN
# 400  4.272701e+05 NaN NaN NaN NaN NaN
# 401  7.380628e+02 NaN NaN NaN NaN NaN
# 402  2.183165e+02 NaN NaN NaN NaN NaN
# 403  4.016711e+02 NaN NaN NaN NaN NaN
# 404  5.551935e+02 NaN NaN NaN NaN NaN
# 405  3.864654e+02 NaN NaN NaN NaN NaN
#
# [406 rows x 9 columns]

# %%
df_cuts = d_noise[d_noise['Sw']<600]

# %%
len(df_cuts)
# Out:
# 350

# %%
figure(figsize = (8,6))
hist(d_noise['Sw'], bins = 28, range = (0,500), color = 'k', edgecolor='black', linewidth=1, alpha=0.4);
axvline(median(d_noise['Sw']), alpha =0.8, lw=3, label = '$\mathrm{median: %3.0f~pA (Hz)^{-1/2}}$' % median(df_cuts['Sw']), color = 'darkblue')
axvline(150, color = 'darkred', alpha =0.8, lw=3, label = '$\mathrm{expected\ photon\ noise: 150~pA (Hz)^{-1/2}}$')
xlabel('$S_\mathrm{w}~\mathrm{[pA/ \sqrt{Hz}]}$')
ylabel('$\mathrm{channel\ number}$')
legend(fontsize = 14)
tight_layout()
savefig('20190812_4GHz_white_noise_hist.pdf')
